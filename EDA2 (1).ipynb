# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
Adults=pd.read_csv("/content/adult_with_headers.csv")

# %%
Adults.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
Adults['capital_gain']
# Out:
# 0         2174
# 1            0
# 2            0
# 3            0
# 4            0
#          ...
# 32556        0
# 32557        0
# 32558        0
# 32559        0
# 32560    15024
# Name: capital_gain, Length: 32561, dtype: int64

# %%
Adults['capital_gain'].unique()
# Out:
# array([ 2174,     0, 14084,  5178,  5013,  2407, 14344, 15024,  7688,
#        34095,  4064,  4386,  7298,  1409,  3674,  1055,  3464,  2050,
#         2176,   594, 20051,  6849,  4101,  1111,  8614,  3411,  2597,
#        25236,  4650,  9386,  2463,  3103, 10605,  2964,  3325,  2580,
#         3471,  4865, 99999,  6514,  1471,  2329,  2105,  2885, 25124,
#        10520,  2202,  2961, 27828,  6767,  2228,  1506, 13550,  2635,
#         5556,  4787,  3781,  3137,  3818,  3942,   914,   401,  2829,
#         2977,  4934,  2062,  2354,  5455, 15020,  1424,  3273, 22040,
#         4416,  3908, 10566,   991,  4931,  1086,  7430,  6497,   114,
#         7896,  2346,  3418,  3432,  2907,  1151,  2414,  2290, 15831,
#        41310,  4508,  2538,  3456,  6418,  1848,  3887,  5721,  9562,
#         1455,  2036,  1831, 11678,  2936,  2993,  7443,  6360,  1797,
#         1173,  4687,  6723,  2009,  6097,  2653,  1639, 18481,  7978,
#         2387,  5060])

# %%
Adults.shape
# Out:
# (32561, 15)

# %%
Adults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
Adults.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
Adults.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
Adults[Adults['age'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_week, native_country, income]
# Index: []

# %%
Adults.tail()
# Out:
#        age      workclass  fnlwgt    education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# 32556             0             0              38   United-States   <=50K
# 32557             0             0              40   United-States    >50K
# 32558             0             0              40   United-States   <=50K
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K

# %%
Adults.drop(['education','marital_status','relationship','race'],axis=1,inplace=True)

# %%
Adults
# Out:
#        age          workclass  fnlwgt  education_num          occupation  \
# 0       39          State-gov   77516             13        Adm-clerical
# 1       50   Self-emp-not-inc   83311             13     Exec-managerial
# 2       38            Private  215646              9   Handlers-cleaners
# 3       53            Private  234721              7   Handlers-cleaners
# 4       28            Private  338409             13      Prof-specialty
# ...    ...                ...     ...            ...                 ...
# 32556   27            Private  257302             12        Tech-support
# 32557   40            Private  154374              9   Machine-op-inspct
# 32558   58            Private  151910              9        Adm-clerical
# 32559   22            Private  201490              9        Adm-clerical
# 32560   52       Self-emp-inc  287927              9     Exec-managerial
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 11 columns]

# %%
Adults['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
Adults['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
Adults['education_num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8])

# %%
Adults['age'].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87])

# %%
Adults['hours_per_week'].unique()
# Out:
# array([40, 13, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95])

# %%
Adults['fnlwgt'].unique()
# Out:
# array([ 77516,  83311, 215646, ...,  34066,  84661, 257302])

# %%
Adults['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
Adults1=Adults.copy()

# %%
le=LabelEncoder()
Adults1['workclass']=le.fit_transform(Adults1['workclass'])
Adults1['occupation']=le.fit_transform(Adults1['occupation'])
Adults1['native_country']=le.fit_transform(Adults1['native_country'])
Adults1['sex']=le.fit_transform(Adults1['sex'])
Adults1['income']=le.fit_transform(Adults1['income'])

# %%
Adults1
# Out:
#        age  workclass  fnlwgt  education_num  occupation  sex  capital_gain  \
# 0       39          7   77516             13           1    1          2174
# 1       50          6   83311             13           4    1             0
# 2       38          4  215646              9           6    1             0
# 3       53          4  234721              7           6    1             0
# 4       28          4  338409             13          10    0             0
# ...    ...        ...     ...            ...         ...  ...           ...
# 32556   27          4  257302             12          13    0             0
# 32557   40          4  154374              9           7    1             0
# 32558   58          4  151910              9           1    0             0
# 32559   22          4  201490              9           1    1             0
# 32560   52          5  287927              9           4    0         15024
#
#        capital_loss  hours_per_week  native_country  income
# 0                 0              40              39       0
# 1                 0              13              39       0
# 2                 0              40              39       0
# 3                 0              40              39       0
# 4                 0              40               5       0
# ...             ...             ...             ...     ...
# 32556             0              38              39       0
# 32557             0              40              39       1
# 32558             0              40              39       0
# 32559             0              20              39       0
# 32560             0              40              39       1
#
# [32561 rows x 11 columns]

# %%
Adults1['workclass']
# Out:
# 0        7
# 1        6
# 2        4
# 3        4
# 4        4
#         ..
# 32556    4
# 32557    4
# 32558    4
# 32559    4
# 32560    5
# Name: workclass, Length: 32561, dtype: int64

# %%
Adults2=Adults.copy()

# %% [markdown]
# ONE HOT ENCODER

# %%
from sklearn.preprocessing import OneHotEncoder
enc= OneHotEncoder()
Adults2['sex']=pd.DataFrame(enc.fit_transform(Adults2['sex'].values.reshape(-1,1)))
Adults2['income']=pd.DataFrame(enc.fit_transform(Adults2['income'].values.reshape(-1,1)))
Adults2['workclass']=pd.DataFrame(enc.fit_transform(Adults2['workclass'].array.reshape(-1,1)))
Adults2['occupation']=pd.DataFrame(enc.fit_transform(Adults2['occupation'].array.reshape(-1,1)))
Adults2['native_country']=pd.DataFrame(enc.fit_transform(Adults2['native_country'].array.reshape(-1,1)))

# %%
Adults2
# Out:
#        age      workclass  fnlwgt  education_num      occupation  \
# 0       39    (0, 7)\t1.0   77516             13     (0, 1)\t1.0
# 1       50    (0, 6)\t1.0   83311             13     (0, 4)\t1.0
# 2       38    (0, 4)\t1.0  215646              9     (0, 6)\t1.0
# 3       53    (0, 4)\t1.0  234721              7     (0, 6)\t1.0
# 4       28    (0, 4)\t1.0  338409             13    (0, 10)\t1.0
# ...    ...            ...     ...            ...             ...
# 32556   27    (0, 4)\t1.0  257302             12    (0, 13)\t1.0
# 32557   40    (0, 4)\t1.0  154374              9     (0, 7)\t1.0
# 32558   58    (0, 4)\t1.0  151910              9     (0, 1)\t1.0
# 32559   22    (0, 4)\t1.0  201490              9     (0, 1)\t1.0
# 32560   52    (0, 5)\t1.0  287927              9     (0, 4)\t1.0
#
#                  sex  capital_gain  capital_loss  hours_per_week  \
# 0        (0, 1)\t1.0          2174             0              40
# 1        (0, 1)\t1.0             0             0              13
# 2        (0, 1)\t1.0             0             0              40
# 3        (0, 1)\t1.0             0             0              40
# 4        (0, 0)\t1.0             0             0              40
# ...              ...           ...           ...             ...
# 32556    (0, 0)\t1.0             0             0              38
# 32557    (0, 1)\t1.0             0             0              40
# 32558    (0, 0)\t1.0             0             0              40
# 32559    (0, 1)\t1.0             0             0              20
# 32560    (0, 0)\t1.0         15024             0              40
#
#        native_country         income
# 0        (0, 39)\t1.0    (0, 0)\t1.0
# 1        (0, 39)\t1.0    (0, 0)\t1.0
# 2        (0, 39)\t1.0    (0, 0)\t1.0
# 3        (0, 39)\t1.0    (0, 0)\t1.0
# 4         (0, 5)\t1.0    (0, 0)\t1.0
# ...               ...            ...
# 32556    (0, 39)\t1.0    (0, 0)\t1.0
# 32557    (0, 39)\t1.0    (0, 1)\t1.0
# 32558    (0, 39)\t1.0    (0, 0)\t1.0
# 32559    (0, 39)\t1.0    (0, 0)\t1.0
# 32560    (0, 39)\t1.0    (0, 1)\t1.0
#
# [32561 rows x 11 columns]

# %% [markdown]
# Adults1 encoded with labelencoder and Adults2 encoded with One Hot Encoder but one Hot encoder provide multiple columns for each variable, so label encoder is better since the data is huge

# %%
Adults.groupby(['capital_gain','income','occupation']).size()
# Out:
# capital_gain  income  occupation
# 0              <=50K   ?                   1576
#                        Adm-clerical        3128
#                        Armed-Forces           8
#                        Craft-repair        3035
#                        Exec-managerial     1996
#                                            ...
# 99999          >50K    Prof-specialty        67
#                        Protective-serv        1
#                        Sales                 25
#                        Tech-support           1
#                        Transport-moving       1
# Length: 718, dtype: int64

# %%
Adults.groupby(['capital_loss','income','occupation']).size()
# Out:
# capital_loss  income  occupation
# 0              <=50K   ?                    1610
#                        Adm-clerical         3167
#                        Armed-Forces            8
#                        Craft-repair         3053
#                        Exec-managerial      2023
#                                             ...
# 3770           <=50K   Other-service           1
# 3900           <=50K   Machine-op-inspct       1
#                        Prof-specialty          1
# 4356           <=50K   ?                       2
#                        Exec-managerial         1
# Length: 512, dtype: int64

# %%
sns.barplot(x='occupation',y='income',hue='sex',data=Adults1)
# Out:
# <Axes: xlabel='occupation', ylabel='income'>

# %%
sns.barplot(x='capital_gain',y='income',data=Adults1)
# Out:
# <Axes: xlabel='capital_gain', ylabel='income'>

# %%
sns.barplot(x='capital_loss',y='income',data=Adults1)
# Out:
# <Axes: xlabel='capital_loss', ylabel='income'>

# %%
sns.scatterplot(x='capital_gain',y='income',hue='sex',data=Adults1)
# Out:
# <Axes: xlabel='capital_gain', ylabel='income'>

# %%
sns.scatterplot(x='capital_loss',y='income',hue='sex',data=Adults1)
# Out:
# <Axes: xlabel='capital_loss', ylabel='income'>

# %%
sns.scatterplot(x='fnlwgt',y='income',hue='sex',data=Adults1)
# Out:
# <Axes: xlabel='fnlwgt', ylabel='income'>

# %%
Adults1
# Out:
#        age  workclass  fnlwgt  education_num  occupation  sex  capital_gain  \
# 0       39          7   77516             13           1    1          2174
# 1       50          6   83311             13           4    1             0
# 2       38          4  215646              9           6    1             0
# 3       53          4  234721              7           6    1             0
# 4       28          4  338409             13          10    0             0
# ...    ...        ...     ...            ...         ...  ...           ...
# 32556   27          4  257302             12          13    0             0
# 32557   40          4  154374              9           7    1             0
# 32558   58          4  151910              9           1    0             0
# 32559   22          4  201490              9           1    1             0
# 32560   52          5  287927              9           4    0         15024
#
#        capital_loss  hours_per_week  native_country  income
# 0                 0              40              39       0
# 1                 0              13              39       0
# 2                 0              40              39       0
# 3                 0              40              39       0
# 4                 0              40               5       0
# ...             ...             ...             ...     ...
# 32556             0              38              39       0
# 32557             0              40              39       1
# 32558             0              40              39       0
# 32559             0              20              39       0
# 32560             0              40              39       1
#
# [32561 rows x 11 columns]

# %%
sns.scatterplot(x='workclass',y='income',data=Adults)
# Out:
# <Axes: xlabel='workclass', ylabel='income'>

# %%
Adults1.corr()
# Out:
#                      age  workclass    fnlwgt  education_num  occupation  \
# age             1.000000   0.003787 -0.076646       0.036527   -0.020947
# workclass       0.003787   1.000000 -0.016656       0.052085    0.254892
# fnlwgt         -0.076646  -0.016656  1.000000      -0.043195    0.001597
# education_num   0.036527   0.052085 -0.043195       1.000000    0.109697
# occupation     -0.020947   0.254892  0.001597       0.109697    1.000000
# sex             0.088832   0.095981  0.026858       0.012280    0.080296
# capital_gain    0.077674   0.033835  0.000432       0.122630    0.025505
# capital_loss    0.057775   0.012216 -0.010252       0.079923    0.017987
# hours_per_week  0.068756   0.138962 -0.018768       0.148123    0.080383
# native_country -0.001151  -0.007690 -0.051966       0.050840   -0.012543
# income          0.234037   0.051604 -0.009463       0.335154    0.075468
#
#                      sex  capital_gain  capital_loss  hours_per_week  \
# age             0.088832      0.077674      0.057775        0.068756
# workclass       0.095981      0.033835      0.012216        0.138962
# fnlwgt          0.026858      0.000432     -0.010252       -0.018768
# education_num   0.012280      0.122630      0.079923        0.148123
# occupation      0.080296      0.025505      0.017987        0.080383
# sex             1.000000      0.048480      0.045567        0.229309
# capital_gain    0.048480      1.000000     -0.031615        0.078409
# capital_loss    0.045567     -0.031615      1.000000        0.054256
# hours_per_week  0.229309      0.078409      0.054256        1.000000
# native_country -0.008119     -0.001982      0.000419       -0.002671
# income          0.215980      0.223329      0.150526        0.229689
#
#                 native_country    income
# age                  -0.001151  0.234037
# workclass            -0.007690  0.051604
# fnlwgt               -0.051966 -0.009463
# education_num         0.050840  0.335154
# occupation           -0.012543  0.075468
# sex                  -0.008119  0.215980
# capital_gain         -0.001982  0.223329
# capital_loss          0.000419  0.150526
# hours_per_week       -0.002671  0.229689
# native_country        1.000000  0.015840
# income                0.015840  1.000000

# %% [markdown]
# there is no proper correlation between fnlwgt and income

# %%
Adults1.corr()['income']
# Out:
# age               0.234037
# workclass         0.051604
# fnlwgt           -0.009463
# education_num     0.335154
# occupation        0.075468
# sex               0.215980
# capital_gain      0.223329
# capital_loss      0.150526
# hours_per_week    0.229689
# native_country    0.015840
# income            1.000000
# Name: income, dtype: float64

# %%
#drop fnlwgt from Adults1 dataset
Adults1.drop(['fnlwgt'],axis=1,inplace=True)

# %%
Adults1
# Out:
#        age  workclass  education_num  occupation  sex  capital_gain  \
# 0       39          7             13           1    1          2174
# 1       50          6             13           4    1             0
# 2       38          4              9           6    1             0
# 3       53          4              7           6    1             0
# 4       28          4             13          10    0             0
# ...    ...        ...            ...         ...  ...           ...
# 32556   27          4             12          13    0             0
# 32557   40          4              9           7    1             0
# 32558   58          4              9           1    0             0
# 32559   22          4              9           1    1             0
# 32560   52          5              9           4    0         15024
#
#        capital_loss  hours_per_week  native_country  income
# 0                 0              40              39       0
# 1                 0              13              39       0
# 2                 0              40              39       0
# 3                 0              40              39       0
# 4                 0              40               5       0
# ...             ...             ...             ...     ...
# 32556             0              38              39       0
# 32557             0              40              39       1
# 32558             0              40              39       0
# 32559             0              20              39       0
# 32560             0              40              39       1
#
# [32561 rows x 10 columns]

# %% [markdown]
# feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler(copy=True,with_mean=True,with_std=True)

# %%
Adults1=scaler.fit_transform(Adults1)

# %%
Adults3=pd.DataFrame(Adults1)

# %%
Adults3
# Out:
#               0         1         2         3         4         5        6  \
# 0      0.030671  2.150579  1.134739 -1.317809  0.703071  0.148453 -0.21666
# 1      0.837109  1.463736  1.134739 -0.608387  0.703071 -0.145920 -0.21666
# 2     -0.042642  0.090050 -0.420060 -0.135438  0.703071 -0.145920 -0.21666
# 3      1.057047  0.090050 -1.197459 -0.135438  0.703071 -0.145920 -0.21666
# 4     -0.775768  0.090050  1.134739  0.810458 -1.422331 -0.145920 -0.21666
# ...         ...       ...       ...       ...       ...       ...      ...
# 32556 -0.849080  0.090050  0.746039  1.519881 -1.422331 -0.145920 -0.21666
# 32557  0.103983  0.090050 -0.420060  0.101036  0.703071 -0.145920 -0.21666
# 32558  1.423610  0.090050 -0.420060 -1.317809 -1.422331 -0.145920 -0.21666
# 32559 -1.215643  0.090050 -0.420060 -1.317809  0.703071 -0.145920 -0.21666
# 32560  0.983734  0.776893 -0.420060 -0.608387 -1.422331  1.888424 -0.21666
#
#               7         8         9
# 0     -0.035429  0.291569 -0.563199
# 1     -2.222153  0.291569 -0.563199
# 2     -0.035429  0.291569 -0.563199
# 3     -0.035429  0.291569 -0.563199
# 4     -0.035429 -4.054223 -0.563199
# ...         ...       ...       ...
# 32556 -0.197409  0.291569 -0.563199
# 32557 -0.035429  0.291569  1.775573
# 32558 -0.035429  0.291569 -0.563199
# 32559 -1.655225  0.291569 -0.563199
# 32560 -0.035429  0.291569  1.775573
#
# [32561 rows x 10 columns]

# %% [markdown]
# Isolation Forest

# %%
from sklearn.ensemble import IsolationForest

# %%
clf=IsolationForest(random_state=10,contamination=0.01)

# %%
clf.fit(Adults3)
# Out:
# IsolationForest(contamination=0.01, random_state=10)

# %%
y_pred_outliers=clf.predict(Adults3)

# %%
y_pred_outliers
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_pred_outliers.shape
# Out:
# (32561,)

# %%
y_pred_outliers.sum()
# Out:
# 31909

# %%
y_pred_outliers.mean()
# Out:
# 0.979976044961764

# %%
y_pred_outliers.max()
# Out:
# 1

# %%
y_pred_outliers.min()
# Out:
# -1

# %%
y_pred_outliers.std()
# Out:
# 0.19911542205740507

# %%
y_pred_outliers=pd.DataFrame(y_pred_outliers)

# %%
y_pred_outliers
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 32556  1
# 32557  1
# 32558  1
# 32559  1
# 32560  1
#
# [32561 rows x 1 columns]

# %%
Adults3.shape
# Out:
# (32561, 10)

# %%
clf.score_samples(Adults3)
# Out:
# array([-0.45881857, -0.46960731, -0.35090814, ..., -0.41231133,
#        -0.41892285, -0.54520022])

# %%
Adults3.columns=Adults3.columns.astype(str)

# %%
Adults3=Adults3.reset_index()

# %%
Adults3
# Out:
#        index         0         1         2         3         4         5  \
# 0          0  0.030671  2.150579  1.134739 -1.317809  0.703071  0.148453
# 1          1  0.837109  1.463736  1.134739 -0.608387  0.703071 -0.145920
# 2          2 -0.042642  0.090050 -0.420060 -0.135438  0.703071 -0.145920
# 3          3  1.057047  0.090050 -1.197459 -0.135438  0.703071 -0.145920
# 4          4 -0.775768  0.090050  1.134739  0.810458 -1.422331 -0.145920
# ...      ...       ...       ...       ...       ...       ...       ...
# 32556  32556 -0.849080  0.090050  0.746039  1.519881 -1.422331 -0.145920
# 32557  32557  0.103983  0.090050 -0.420060  0.101036  0.703071 -0.145920
# 32558  32558  1.423610  0.090050 -0.420060 -1.317809 -1.422331 -0.145920
# 32559  32559 -1.215643  0.090050 -0.420060 -1.317809  0.703071 -0.145920
# 32560  32560  0.983734  0.776893 -0.420060 -0.608387 -1.422331  1.888424
#
#              6         7         8         9
# 0     -0.21666 -0.035429  0.291569 -0.563199
# 1     -0.21666 -2.222153  0.291569 -0.563199
# 2     -0.21666 -0.035429  0.291569 -0.563199
# 3     -0.21666 -0.035429  0.291569 -0.563199
# 4     -0.21666 -0.035429 -4.054223 -0.563199
# ...        ...       ...       ...       ...
# 32556 -0.21666 -0.197409  0.291569 -0.563199
# 32557 -0.21666 -0.035429  0.291569  1.775573
# 32558 -0.21666 -0.035429  0.291569 -0.563199
# 32559 -0.21666 -1.655225  0.291569 -0.563199
# 32560 -0.21666 -0.035429  0.291569  1.775573
#
# [32561 rows x 11 columns]

# %%
Adults3['Anomaly']=y_pred_outliers

# %%
Adults3=pd.concat([Adults3,Adults3['Anomaly']],axis=1)

# %%
Adults3
# Out:
#        index         0         1         2         3         4         5  \
# 0          0  0.030671  2.150579  1.134739 -1.317809  0.703071  0.148453
# 1          1  0.837109  1.463736  1.134739 -0.608387  0.703071 -0.145920
# 2          2 -0.042642  0.090050 -0.420060 -0.135438  0.703071 -0.145920
# 3          3  1.057047  0.090050 -1.197459 -0.135438  0.703071 -0.145920
# 4          4 -0.775768  0.090050  1.134739  0.810458 -1.422331 -0.145920
# ...      ...       ...       ...       ...       ...       ...       ...
# 32556  32556 -0.849080  0.090050  0.746039  1.519881 -1.422331 -0.145920
# 32557  32557  0.103983  0.090050 -0.420060  0.101036  0.703071 -0.145920
# 32558  32558  1.423610  0.090050 -0.420060 -1.317809 -1.422331 -0.145920
# 32559  32559 -1.215643  0.090050 -0.420060 -1.317809  0.703071 -0.145920
# 32560  32560  0.983734  0.776893 -0.420060 -0.608387 -1.422331  1.888424
#
#              6         7         8         9  Anomaly  Anomaly
# 0     -0.21666 -0.035429  0.291569 -0.563199        1        1
# 1     -0.21666 -2.222153  0.291569 -0.563199        1        1
# 2     -0.21666 -0.035429  0.291569 -0.563199        1        1
# 3     -0.21666 -0.035429  0.291569 -0.563199        1        1
# 4     -0.21666 -0.035429 -4.054223 -0.563199        1        1
# ...        ...       ...       ...       ...      ...      ...
# 32556 -0.21666 -0.197409  0.291569 -0.563199        1        1
# 32557 -0.21666 -0.035429  0.291569  1.775573        1        1
# 32558 -0.21666 -0.035429  0.291569 -0.563199        1        1
# 32559 -0.21666 -1.655225  0.291569 -0.563199        1        1
# 32560 -0.21666 -0.035429  0.291569  1.775573        1        1
#
# [32561 rows x 13 columns]

# %%
Adults3.drop_duplicates()
# Out:
#        index         0         1         2         3         4         5  \
# 0          0  0.030671  2.150579  1.134739 -1.317809  0.703071  0.148453
# 1          1  0.837109  1.463736  1.134739 -0.608387  0.703071 -0.145920
# 2          2 -0.042642  0.090050 -0.420060 -0.135438  0.703071 -0.145920
# 3          3  1.057047  0.090050 -1.197459 -0.135438  0.703071 -0.145920
# 4          4 -0.775768  0.090050  1.134739  0.810458 -1.422331 -0.145920
# ...      ...       ...       ...       ...       ...       ...       ...
# 32556  32556 -0.849080  0.090050  0.746039  1.519881 -1.422331 -0.145920
# 32557  32557  0.103983  0.090050 -0.420060  0.101036  0.703071 -0.145920
# 32558  32558  1.423610  0.090050 -0.420060 -1.317809 -1.422331 -0.145920
# 32559  32559 -1.215643  0.090050 -0.420060 -1.317809  0.703071 -0.145920
# 32560  32560  0.983734  0.776893 -0.420060 -0.608387 -1.422331  1.888424
#
#              6         7         8         9  Anomaly  Anomaly
# 0     -0.21666 -0.035429  0.291569 -0.563199        1        1
# 1     -0.21666 -2.222153  0.291569 -0.563199        1        1
# 2     -0.21666 -0.035429  0.291569 -0.563199        1        1
# 3     -0.21666 -0.035429  0.291569 -0.563199        1        1
# 4     -0.21666 -0.035429 -4.054223 -0.563199        1        1
# ...        ...       ...       ...       ...      ...      ...
# 32556 -0.21666 -0.197409  0.291569 -0.563199        1        1
# 32557 -0.21666 -0.035429  0.291569  1.775573        1        1
# 32558 -0.21666 -0.035429  0.291569 -0.563199        1        1
# 32559 -0.21666 -1.655225  0.291569 -0.563199        1        1
# 32560 -0.21666 -0.035429  0.291569  1.775573        1        1
#
# [32561 rows x 13 columns]

# %%
Adults3.drop(columns=['index','Anomaly'],axis=1,inplace=True)

# %% [markdown]
# PPS score

# %%
# !pip install ppscore
# Out:
# Requirement already satisfied: ppscore in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ppscore) (1.5.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from ppscore) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->ppscore) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->ppscore) (1.16.0)

# %%
import ppscore as pps

# %%
y=Adults1['income']

# %%
pps.matrix(Adults3)
# Out:
#     x  y  ppscore            case  is_valid_score               metric  \
# 0   0  0      1.0  predict_itself            True                 None
# 1   0  1      0.0      regression            True  mean absolute error
# 2   0  2      0.0      regression            True  mean absolute error
# 3   0  3      0.0      regression            True  mean absolute error
# 4   0  4      0.0      regression            True  mean absolute error
# .. .. ..      ...             ...             ...                  ...
# 95  9  5      0.0      regression            True  mean absolute error
# 96  9  6      0.0      regression            True  mean absolute error
# 97  9  7      0.0      regression            True  mean absolute error
# 98  9  8      0.0      regression            True  mean absolute error
# 99  9  9      1.0  predict_itself            True                 None
#
#     baseline_score  model_score                    model
# 0         0.000000     1.000000                     None
# 1         0.510049     0.601455  DecisionTreeRegressor()
# 2         0.720260     0.737871  DecisionTreeRegressor()
# 3         0.887629     0.890108  DecisionTreeRegressor()
# 4         0.714135     0.937639  DecisionTreeRegressor()
# ..             ...          ...                      ...
# 95        0.148119     0.238408  DecisionTreeRegressor()
# 96        0.235616     0.437423  DecisionTreeRegressor()
# 97        0.620090     0.655822  DecisionTreeRegressor()
# 98        0.303541     0.542414  DecisionTreeRegressor()
# 99        0.000000     1.000000                     None
#
# [100 rows x 9 columns]
