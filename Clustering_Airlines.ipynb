# %%
## Hierarchial Clustering
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
h_data=pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
h_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
Scale=MinMaxScaler()
h_data_norm=Scale.fit_transform(h_data)
h_data_norm
# Out:
# array([[0.00000000e+00, 1.65077268e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 8.43742464e-01, 0.00000000e+00],
#        [2.48756219e-04, 1.12878760e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 8.39884254e-01, 0.00000000e+00],
#        [4.97512438e-04, 2.42568502e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 8.47841813e-01, 0.00000000e+00],
#        ...,
#        [9.99502488e-01, 4.31694976e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 1.68796721e-01, 1.00000000e+00],
#        [9.99751244e-01, 3.22018866e-02, 0.00000000e+00, ...,
#         1.88679245e-02, 1.68676151e-01, 0.00000000e+00],
#        [1.00000000e+00, 1.76908304e-03, 0.00000000e+00, ...,
#         0.00000000e+00, 1.68314444e-01, 0.00000000e+00]])

# %%
h_data_norm = pd.DataFrame(h_data_norm)
h_data_norm
# Out:
#             0         1    2     3    4    5         6         7         8   \
# 0     0.000000  0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000
# 1     0.000249  0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000
# 2     0.000498  0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000
# 3     0.000746  0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000
# 4     0.000995  0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398
# ...        ...       ...  ...   ...  ...  ...       ...       ...       ...
# 3994  0.999005  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490
# 3995  0.999254  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000
# 3996  0.999502  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000
# 3997  0.999751  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225
# 3998  1.000000  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000
#
#             9         10   11
# ...

# %%
from scipy.cluster.hierarchy import linkage
link=linkage(h_data_norm,method='average',metric='euclidean')
link
# Out:
# array([[2.67800000e+03, 2.67900000e+03, 4.50831038e-04, 2.00000000e+00],
#        [4.06000000e+02, 4.08000000e+02, 7.15642994e-04, 2.00000000e+00],
#        [1.02000000e+02, 1.04000000e+02, 8.34221398e-04, 2.00000000e+00],
#        ...,
#        [7.99200000e+03, 7.99300000e+03, 1.21977299e+00, 1.47700000e+03],
#        [7.99100000e+03, 7.99400000e+03, 1.28085457e+00, 3.99500000e+03],
#        [7.98500000e+03, 7.99500000e+03, 1.72641810e+00, 3.99900000e+03]])

# %%
from scipy.cluster.hierarchy import dendrogram
dend=dendrogram(link)

# %%
from sklearn.cluster import AgglomerativeClustering
Agg_clust=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='average')

# %%
Agg_clust.fit(h_data_norm)
# Out:
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# AgglomerativeClustering(affinity='euclidean', linkage='average', n_clusters=5)

# %%
Agg_clust.get_params
# Out:
# <bound method BaseEstimator.get_params of AgglomerativeClustering(affinity='euclidean', linkage='average', n_clusters=5)>

# %%
Agg_clust.labels_
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int64)

# %%
h_labels=Agg_clust.labels_

# %%
h_data['clusters']=h_labels

# %%
h_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
h_data.iloc[:,1:].groupby(h_data['clusters']).mean()
# Out:
#                 Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusters
# 0          95829.510929  241.230191   2.647541    1.01571   1.000683
# 1          76565.125000  147.750000   3.875000    1.00000   4.250000
# 2          59807.839555   87.602462   1.705322    1.01390   1.008737
# 3         131999.500000  347.000000   2.500000    1.00000   1.000000
# 4         460129.200000    0.000000   5.000000    1.00000   1.000000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusters
# 0          27652.528005    15.504781         799.812842         2.459016
# 1         115273.250000    30.250000         600.000000         2.000000
# 2          10227.689039     9.142971         226.292295         0.652502
# 3          65634.250000    69.250000       19960.000000        49.250000
# 4         228179.000000    31.200000        2878.600000         7.400000
#
#           Days_since_enroll  Award?  clusters
# clusters
# ...

# %%
h_data['clusters'].value_counts()
# Out:
# 2    2518
# 0    1464
# 1       8
# 4       5
# 3       4
# Name: clusters, dtype: int64

# %%
from sklearn.metrics import silhouette_score
score=silhouette_score(h_data_norm,h_labels)
score
# Out:
# 0.4245703353468674

# %% [markdown]
# # Performing K Means Clustering

# %%
k_data=pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
k_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
##Standardise data
scale=MinMaxScaler()
k_data_norm=scale.fit_transform(k_data)
k_data_norm=pd.DataFrame(k_data_norm,columns=k_data.columns)
k_data_norm
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
##Plot elbow curve for K value
WCSS=[]
from sklearn.cluster import KMeans
for i in range(1,10):
    model=KMeans(n_clusters=i)
    model=model.fit(k_data_norm)
    WCSS.append(model.inertia_)
plt.plot(range(1,10),WCSS)
# Out:
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
WCSS
# Out:
# [2164.1265977774974,
#  1146.4595170935336,
#  865.2605940455037,
#  673.4748707148151,
#  536.2045491556579,
#  452.22843050741204,
#  397.9456594562287,
#  346.22685211457576,
#  308.5169582079872]

# %%
##From the above curve, we can use k value as 5

# %%
##build KMeans cluster model with no of cluster as 5
k_model=KMeans(n_clusters=5)
k_model=k_model.fit(k_data_norm)
k_model
# Out:
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
k_clust_labels=k_model.labels_

# %%
k_data['Clust_labels']=k_clust_labels
k_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
k_data['Clust_labels'].value_counts()
# Out:
# 0    1113
# 3     862
# 2     792
# 1     689
# 4     543
# Name: Clust_labels, dtype: int64

# %%
k_data.plot(x='Bonus_miles',y='Bonus_trans',kind='scatter',s=50,c=k_clust_labels,cmap=plt.cm.BrBG_r)
# Out:
# <Axes: xlabel='Bonus_miles', ylabel='Bonus_trans'>

# %%
##Calculating Silhoutte SCore to check accuracy of labels
from sklearn.metrics import silhouette_score
k_accuracy=silhouette_score(k_data_norm,k_clust_labels)
k_accuracy
# Out:
# 0.41665908141896746

# %% [markdown]
# # Performing DBScan Clustering

# %%
db_data=pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
db_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
##Standardise the given data:
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
db_data_norm=scale.fit_transform(db_data.iloc[:,1:])
db_data_norm=pd.DataFrame(db_data_norm)
db_data_norm
# Out:
#             0    1     2    3    4         5         6         7         8   \
# 0     0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000  0.000000
# 1     0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000  0.000000
# 2     0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000  0.000000
# 3     0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000  0.000000
# 4     0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398  0.075472
# ...        ...  ...   ...  ...  ...       ...       ...       ...       ...
# 3994  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490  0.018868
# 3995  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000  0.000000
# 3996  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000  0.000000
# 3997  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225  0.018868
# 3998  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
#             9    10
# 0     0.843742  0.0
# ...

# %%
##Find Epsilon Radius using Nearest Neighbours
from sklearn.neighbors import NearestNeighbors
neigh=NearestNeighbors(n_neighbors=22)
neigh=neigh.fit(db_data_norm)
distances,indices=neigh.kneighbors(db_data_norm)

# %%
distances
# Out:
# array([[0.        , 0.00871531, 0.00982329, ..., 0.02932871, 0.02945634,
#         0.03071875],
#        [0.        , 0.01212297, 0.01331785, ..., 0.03473729, 0.03509134,
#         0.03514045],
#        [0.        , 0.01857767, 0.01872551, ..., 0.04552297, 0.04668783,
#         0.04773513],
#        ...,
#        [0.        , 0.02591961, 0.04945468, ..., 0.1198017 , 0.11996173,
#         0.12060709],
#        [0.        , 0.0264501 , 0.02784951, ..., 0.03925554, 0.03970704,
#         0.03979314],
#        [0.        , 0.00038605, 0.0027753 , ..., 0.0198035 , 0.02220023,
#         0.02328785]])

# %%
distances=np.sort(distances,axis=0)

# %%
plt.plot(distances[:,1])

# %%
##We can consider epsilon value of 0.2

# %%
from sklearn.cluster import DBSCAN
db_model=DBSCAN(eps=0.2,min_samples=12)
db_model=db_model.fit(db_data_norm)

# %%
db_model.components_
# Out:
# array([[0.01650773, 0.        , 0.        , ..., 0.        , 0.84374246,
#         0.        ],
#        [0.01128788, 0.        , 0.        , ..., 0.        , 0.83988425,
#         0.        ],
#        [0.02425685, 0.        , 0.        , ..., 0.        , 0.84784181,
#         0.        ],
#        ...,
#        [0.0431695 , 0.        , 0.5       , ..., 0.        , 0.16879672,
#         1.        ],
#        [0.03220189, 0.        , 0.        , ..., 0.01886792, 0.16867615,
#         0.        ],
#        [0.00176908, 0.        , 0.        , ..., 0.        , 0.16831444,
#         0.        ]])

# %%
db_model_labels=pd.DataFrame(db_model.labels_,columns=['DBScan_Labels'])
db_model_labels
# Out:
#       DBScan_Labels
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1
# ...             ...
# 3994              3
# 3995              3
# 3996              4
# 3997              0
# 3998              0
#
# [3999 rows x 1 columns]

# %%
db_data['DBSCan Labels']=db_model_labels
db_data=db_data.drop(columns='ID#',axis=1)
db_data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
db_data.plot(x='Bonus_miles',y='Bonus_trans',cmap=plt.cm.gist_rainbow,kind='scatter',s=80,c=db_data['DBSCan Labels'],figsize=(20,20))
# Out:
# <Axes: xlabel='Bonus_miles', ylabel='Bonus_trans'>

# %%
##Calculate Silhooutte score for clusters
from sklearn.metrics import silhouette_score
db_accuracy=silhouette_score(db_data_norm,db_model_labels)
db_accuracy
# Out:
# C:\Users\Swapna\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.21230627176776276

# %%
##Accuracy Table:
index=['KMeans Score','DBScan Score']
columns=['Silhoutte Score']
labels=[k_accuracy,db_accuracy]
pd.DataFrame(labels,index=index,columns=columns)
# Out:
#               Silhoutte Score
# KMeans Score         0.416659
# DBScan Score         0.212306
